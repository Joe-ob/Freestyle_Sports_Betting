# %% [markdown]
# <a href="https://colab.research.google.com/github/Joe-ob/Freestyle_Sports_Betting/blob/main/Sports_Betting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###ReadMe Contents:

# %% [markdown]
# ###Requirements.txt Contents:

# %% [markdown]
# ###.ENV Code
#
# API_KEY = "46a70b05e16c5bdb663037f8eb80a31b"
#
# https://api.the-odds-api.com/v3/odds/?apiKey=46a70b05e16c5bdb663037f8eb80a31b&sport=baseball_mlb&region=us&mkt=spreads&dateFormat=unix

# %% [markdown]
# # Sample Code

# %%
import json
import requests

# An api key is emailed to you when you sign up to a plan
api_key = "46a70b05e16c5bdb663037f8eb80a31b"


# First get a list of in-season sports
sports_response = requests.get('https://api.the-odds-api.com/v3/sports', params={
    'api_key': api_key
})

sports_json = json.loads(sports_response.text)

if not sports_json['success']:
    print(
        'There was a problem with the sports request:',
        sports_json['msg']
    )

else:
    print()
    print(
        'Successfully got {} sports'.format(len(sports_json['data'])),
        'Here\'s the first sport:'
    )
    print(sports_json['data'][3])



# To get odds for a sepcific sport, use the sport key from the last request
#   or set sport to "upcoming" to see live and upcoming across all sports
sport_key = 'baseball_mlb'                                                      

odds_response = requests.get('https://api.the-odds-api.com/v3/odds', params={
    'api_key': api_key,                                                         
    'sport': sport_key,                                                         
    'region': 'us', # uk | us | eu | au                                         
    'mkt': 'spreads', # h2h | spreads | totals           
    'dateFormat': 'unix'                      #This might be a user input
})

odds_json = json.loads(odds_response.text)
if not odds_json['success']:
    print(
        'There was a problem with the odds request:',
        odds_json['msg']
    )

else:
    # odds_json['data'] contains a list of live and 
    #   upcoming events and odds for different bookmakers.
    # Events are ordered by start time (live events are first)
    print()
    print(
        'Successfully got {} events'.format(len(odds_json['data'])),
        'Here\'s the first event:'
    )

    baseball = (odds_json['data'][3])


    print(baseball)


    # Check your usage
    print()
    print('Remaining requests', odds_response.headers['x-requests-remaining'])
    print('Used requests', odds_response.headers['x-requests-used'])
# Out:
# Successfully got 45 sports Here's the first sport:
# {'key': 'baseball_mlb', 'active': True, 'group': 'Baseball', 'details': 'Major League Baseball 🇺🇸', 'title': 'MLB', 'has_outrights': False}
#
# Successfully got 15 events Here's the first event:
# {'id': 'e907a4ec80943ba33a494a93cd4c26c6', 'sport_key': 'baseball_mlb', 'sport_nice': 'MLB', 'teams': ['Chicago Cubs', 'Detroit Tigers'], 'commence_time': 1621109460, 'home_team': 'Detroit Tigers', 'sites': [{'site_key': 'betonlineag', 'site_nice': 'BetOnline.ag', 'last_update': 1621091689, 'odds': {'spreads': {'odds': [2.16, 1.73], 'points': ['-1.5', '1.5']}}}, {'site_key': 'pointsbetus', 'site_nice': 'PointsBet (US)', 'last_update': 1621091689, 'odds': {'spreads': {'odds': [2.15, 1.74], 'points': ['-1.5', '1.5']}}}, {'site_key': 'gtbets', 'site_nice': 'GTbets', 'last_update': 1621091691, 'odds': {'spreads': {'odds': [2.16, 1.74], 'points': ['-1.5', '1.5']}}}, {'site_key': 'williamhill_us', 'site_nice': 'William Hill (US)', 'last_update': 1621091689, 'odds': {'spreads': {'odds': [2.15, 1.74], 'points': ['-1.5', '1.5']}}}, {'site_key': 'sugarhouse', 'site_nice': 'SugarHouse', 'last_update': 1621091692, 'odds': {'spreads': {'odds': [2.25, 1.66], 'points': ['-1.5', '1.5']}}}, {'site_key': 'barstool', 'site_nice': 'Barstool Sportsbook', 'last_update': 1621091692, 'odds': {'spreads': {'odds': [2.25, 1.66], 'points': ['-1.5', '1.5']}}}, {'site_key': 'unibet', 'site_nice': 'Unibet', 'last_update': 1621091685, 'odds': {'spreads': {'odds': [1.98, 1.86], 'points': ['-1.0', '1.0']}}}, {'site_key': 'betrivers', 'site_nice': 'BetRivers', 'last_update': 1621091690, 'odds': {'spreads': {'odds': [2.25, 1.66], 'points': ['-1.5', '1.5']}}}, {'site_key': 'mybookieag', 'site_nice': 'MyBookie.ag', 'last_update': 1621091688, 'odds': {'spreads': {'odds': [2.2, 1.71], 'points': ['-1.5', '1.5']}}}, {'site_key': 'intertops', 'site_nice': 'Intertops', 'last_update': 1621091688, 'odds': {'spreads': {'odds': [2.15, 1.74], 'points': ['-1.50', '1.50']}}}], 'sites_count': 10}
#
# Remaining requests 427
# Used requests 73

# %% [markdown]
# #Notes
#
# https://api.the-odds-api.com/v3/odds/?apiKey={apiKey}&sport={sport}&region={region}&mkt={mkt}

# %% [markdown]
# #Inputs

# %%
zip_code = input("Please input your Zip Code: ")


try:
  if (len(zip_code)) != 5: 
    raise ValueError()
  elif zip_code.isnumeric() == False:
    raise ValueError()
except ValueError:
  print("Error: Please Enter a valid 5 digit, numeric zip code")
  exit()
# Out:
# Please input your Zip Code: 20007

# %%
sport = input("Please select your Sport (baseball, football, hockey, or basketball): ").lower()

valid_options = ['baseball', 'football', 'hockey', 'basketball']

is_valid = sport not in valid_options

try:
  if is_valid == True: 
    raise ValueError()
except ValueError:
    print("Please enter a valid sport")
    exit()

## Can probably do this cleaner but its not raising an error if I don't make a new variable

selection = sport

if selection == 'baseball':
  selection = 'baseball_mlb'
elif selection == 'football':
  selection = 'americanfootball_nfl'
elif selection == 'hockey':
  selection = 'icehockey_nhl'
elif selection == 'basketball':
  selection = 'basketball_nba'
# Out:
# Please select your Sport (baseball, football, hockey, or basketball): BASEBALL

# %% [markdown]
# #Code

# %%
from datetime import datetime
import time
import pytz

print("--------------------")
print("Disclaimer: This app is not for gambling, it only compares odds from different gambling websites to give you the best information. you must go to the websites displayed to place your bet.")
print("--------------------")
print("Understanding the Odds: These odds show your potential winnings on different websites. If you bet one dollar on the team on the left or right, and they win, you will recieve the corresponding winnings in return. If your team loses, you recieve nothing. Good Luck Betting!")
print("--------------------")



if odds_json['success'] == True:
  for item in odds_json['data']:
      #print(item.keys())
      commence_datetime = item['commence_time']
      ts = int(commence_datetime)
      dt_utc = datetime.utcfromtimestamp(ts)
      dt_est = dt_utc.astimezone(pytz.timezone('US/Eastern'))
      game_start_date = dt_est.date()
      game_start_time = dt_est.time()
      print(f"For the game between {item['teams']} that starts at {game_start_time} on {game_start_date},")
      for site in item["sites"]:
          print(f"The odds on  {site['site_nice']} are {site['odds']['spreads']['odds']}")
      print("-----")
      print("-----")
else:
      print(f"It appears there are no {sport_key} games today, make sure this sport is in season or try another sport.")

# %%
##Base Code
import json
import requests
from datetime import datetime
import time 
import pytz


# An api key is emailed to you when you sign up to a plan
api_key = '46a70b05e16c5bdb663037f8eb80a31b'
# First get a list of in-season sports

sports_response = requests.get('https://api.the-odds-api.com/v3/sports', params={
    'api_key': api_key
})
sports_json = json.loads(sports_response.text)
if not sports_json['success']:
    print(
        'There was a problem with the sports request:',
        sports_json['msg']
    )
#else:
#    print()
#    print(
#        'Successfully got {} sports'.format(len(sports_json['data'])),
#        'Here\'s the first sport:'
#    )
#    print(sports_json['data'][3])
# To get odds for a sepcific sport, use the sport key from the last request
#   or set sport to "upcoming" to see live and upcoming across all sports

###User Input for the Zip Code (with Data Validation) to verify Legal Betting in each State
zip_code = input("Please input your Zip Code: ")
try:
  if (len(zip_code)) != 5: 
    raise ValueError()
  elif zip_code.isnumeric() == False:
    raise ValueError()
except ValueError:
  print("Error: Please Enter a valid 5 digit, numeric zip code")
  exit()


#Use Will's code to say if you live in a certain state, say online betting is illegal


###User Input for Sport Selection
sport = input("Please select your Sport (baseball, football, hockey, or basketball): ")
valid_options = ['baseball', 'football', 'hockey', 'basketball']
is_valid = sport not in valid_options
try:
  if is_valid == True: 
    raise ValueError()
except ValueError:
    print("Please enter a valid sport")
    exit()

## Can probably do this cleaner but its not raising an error if I don't make a new variable
sport_selection = sport
if sport_selection == 'baseball':
  sport_selection = 'baseball_mlb'
elif sport_selection == 'football':
  sport_selection = 'americanfootball_nfl'
elif sport_selection == 'hockey':
  sport_selection = 'icehockey_nhl'
elif sport_selection == 'basketball':
  sport_selection = 'basketball_nba'



#sport_selection = 'baseball_mlb'                                                      
odds_response = requests.get('https://api.the-odds-api.com/v3/odds', params={
    'api_key': api_key,                                                         #This should be in a .env file as instructed in the ReadMe file
    'sport': sport_selection,                                                         #This should definitely be a user input
    'region': 'us', # uk | us | eu | au                                         #I think we assume US
    'mkt': 'spreads', # h2h | spreads | totals           
    'dateFormat': 'unix'                      #This might be a user input
})
odds_json = json.loads(odds_response.text)
if not odds_json['success']:
    print(
        'There was a problem with the odds request:',
        odds_json['msg']
    )
else:
    # odds_json['data'] contains a list of live and 
    #   upcoming events and odds for different bookmakers.
    # Events are ordered by start time (live events are first)
    print("--------------------")
    print("Disclaimer: This app is not for gambling, it only displays odds, you must go to the websites displayed to place your bet.")
    print("--------------------")
    print("Understanding the Odds: These odds show your return on investment. If you bet one dollar on the team on the left or right, and they win, you will recieve the corresponding winnings in return. If your team loses, you recieve nothing. Good Luck Betting!")
    print("--------------------")

    if odds_json['success'] == True:
      for item in odds_json['data']:
          #print(item.keys())
          commence_datetime = item['commence_time']
          ts = int(commence_datetime)
          dt_utc = datetime.utcfromtimestamp(ts)
          dt_est = dt_utc.astimezone(pytz.timezone('US/Eastern'))
          game_start_date = dt_est.date()
          game_start_time = dt_est.time()
          print(f"For the game between {item['teams']} that starts at {game_start_time} on {game_start_date},")
          for site in item["sites"]:
              print(f"The odds on  {site['site_nice']} are {site['odds']['spreads']['odds']}")
          print("-----")
          print("-----")
    else:
          print(f"It appears there are no {sport_key} games today, make sure this sport is in season or try another sport.")

        #'Successfully got {} events'.format(len(odds_json['data'])),
        #'Here\'s the first event:'
    
    game_odds = (odds_json['data'][3])
    #print(game_odds)
    # Check your usage
    print()
    print('Remaining requests', odds_response.headers['x-requests-remaining'])
    print('Used requests', odds_response.headers['x-requests-used'])
    


###Figuring out how to search by team
#team_selection = input("Please enter the name of the team you would like to search for: ")
# Out:
# Please input your Zip Code: 19083
# Please select your Sport (baseball, football, hockey, or basketball): baseball
# --------------------
# Disclaimer: This app is not for gambling, it only displays odds, you must go to the websites displayed to place your bet.
# --------------------
# Understanding the Odds: These odds show your return on investment. If you bet one dollar on the team on the left or right, and they win, you will recieve the corresponding winnings in return. If your team loses, you recieve nothing. Good Luck Betting!
# --------------------
# For the game between ['New York Mets', 'Tampa Bay Rays'] that starts at 13:10:00 on 2021-05-15,
# The odds on  SugarHouse are [1.56, 2.45]
# The odds on  BetRivers are [1.56, 2.45]
# The odds on  Barstool Sportsbook are [1.56, 2.45]
# The odds on  Unibet are [1.84, 2.0]
# The odds on  William Hill (US) are [1.62, 2.4]
# The odds on  BetOnline.ag are [1.65, 2.33]
# The odds on  Intertops are [1.65, 2.35]
# The odds on  MyBookie.ag are [1.61, 2.4]
# The odds on  GTbets are [1.65, 2.33]
# The odds on  PointsBet (US) are [1.62, 2.35]
# -----
# -----
# For the game between ['Minnesota Twins', 'Oakland Athletics'] that starts at 16:05:00 on 2021-05-15,
# The odds on  Unibet are [1.95, 1.9]
# The odds on  BetRivers are [2.4, 1.6]
# The odds on  William Hill (US) are [2.4, 1.62]
# The odds on  GTbets are [2.35, 1.65]
# The odds on  BetOnline.ag are [2.35, 1.64]
# The odds on  PointsBet (US) are [2.35, 1.62]
# The odds on  SugarHouse are [2.4, 1.6]
# The odds on  Barstool Sportsbook are [2.4, 1.6]
# The odds on  MyBookie.ag are [2.35, 1.62]
# The odds on  Intertops are [2.35, 1.65]
# -----
# -----
# For the game between ['Boston Red Sox', 'Los Angeles Angels'] that starts at 16:10:00 on 2021-05-15,
# The odds on  Unibet are [1.73, 2.15]
# The odds on  BetRivers are [1.6, 2.4]
# The odds on  William Hill (US) are [1.62, 2.4]
# The odds on  GTbets are [1.65, 2.35]
# The odds on  BetOnline.ag are [1.64, 2.35]
# The odds on  PointsBet (US) are [1.62, 2.35]
# The odds on  SugarHouse are [1.6, 2.4]
# The odds on  Barstool Sportsbook are [1.6, 2.4]
# The odds on  MyBookie.ag are [1.62, 2.35]
# The odds on  Intertops are [1.65, 2.35]
# -----
# -----
# For the game between ['Chicago Cubs', 'Detroit Tigers'] that starts at 16:11:00 on 2021-05-15,
# The odds on  BetOnline.ag are [2.16, 1.73]
# The odds on  PointsBet (US) are [2.15, 1.74]
# The odds on  GTbets are [2.16, 1.74]
# The odds on  William Hill (US) are [2.15, 1.74]
# The odds on  SugarHouse are [2.25, 1.66]
# The odds on  Barstool Sportsbook are [2.25, 1.66]
# The odds on  Unibet are [1.98, 1.86]
# The odds on  BetRivers are [2.25, 1.66]
# The odds on  MyBookie.ag are [2.2, 1.71]
# The odds on  Intertops are [2.15, 1.74]
# -----
# -----
# For the game between ['Pittsburgh Pirates', 'San Francisco Giants'] that starts at 18:35:00 on 2021-05-15,
# The odds on  Unibet are [1.73, 2.16]
# The odds on  BetRivers are [1.56, 2.48]
# The odds on  William Hill (US) are [1.62, 2.4]
# The odds on  GTbets are [1.65, 2.35]
# The odds on  BetOnline.ag are [1.64, 2.35]
# The odds on  PointsBet (US) are [1.62, 2.35]
# The odds on  SugarHouse are [1.56, 2.48]
# The odds on  Barstool Sportsbook are [1.56, 2.48]
# The odds on  MyBookie.ag are [1.62, 2.35]
# The odds on  Intertops are [1.67, 2.3]
# -----
# -----
# For the game between ['Baltimore Orioles', 'New York Yankees'] that starts at 19:05:00 on 2021-05-15,
# The odds on  Unibet are [2.02, 1.84]
# The odds on  BetRivers are [1.76, 2.1]
# The odds on  William Hill (US) are [1.8, 2.05]
# The odds on  GTbets are [1.82, 2.02]
# The odds on  BetOnline.ag are [1.82, 2.02]
# The odds on  PointsBet (US) are [1.83, 2.0]
# The odds on  SugarHouse are [1.76, 2.1]
# The odds on  Barstool Sportsbook are [1.76, 2.1]
# The odds on  MyBookie.ag are [1.83, 2.0]
# The odds on  Intertops are [1.87, 1.95]
# -----
# -----
# For the game between ['Chicago White Sox', 'Kansas City Royals'] that starts at 19:10:00 on 2021-05-15,
# The odds on  Unibet are [2.15, 1.73]
# The odds on  BetRivers are [2.15, 1.73]
# The odds on  William Hill (US) are [2.05, 1.8]
# The odds on  GTbets are [2.06, 1.79]
# The odds on  BetOnline.ag are [2.06, 1.79]
# The odds on  PointsBet (US) are [2.05, 1.8]
# The odds on  SugarHouse are [2.15, 1.73]
# The odds on  Barstool Sportsbook are [2.15, 1.73]
# The odds on  MyBookie.ag are [2.05, 1.8]
# The odds on  Intertops are [2.0, 1.83]
# -----
# -----
# For the game between ['Houston Astros', 'Texas Rangers'] that starts at 19:10:00 on 2021-05-15,
# The odds on  Unibet are [1.8, 2.06]
# The odds on  BetRivers are [2.14, 1.73]
# The odds on  William Hill (US) are [2.1, 1.77]
# The odds on  GTbets are [2.1, 1.77]
# The odds on  BetOnline.ag are [2.1, 1.76]
# The odds on  PointsBet (US) are [2.1, 1.76]
# The odds on  SugarHouse are [2.14, 1.73]
# The odds on  Barstool Sportsbook are [2.14, 1.73]
# The odds on  MyBookie.ag are [2.1, 1.77]
# The odds on  Intertops are [2.1, 1.77]
# -----
# -----
# For the game between ['Atlanta Braves', 'Milwaukee Brewers'] that starts at 19:11:00 on 2021-05-15,
# The odds on  BetOnline.ag are [2.48, 1.59]
# The odds on  William Hill (US) are [2.45, 1.59]
# The odds on  Barstool Sportsbook are [2.48, 1.56]
# The odds on  BetRivers are [2.48, 1.56]
# The odds on  SugarHouse are [2.48, 1.56]
# The odds on  Unibet are [2.17, 1.73]
# The odds on  GTbets are [2.48, 1.6]
# The odds on  Intertops are [2.45, 1.61]
# The odds on  MyBookie.ag are [2.45, 1.59]
# The odds on  PointsBet (US) are [2.45, 1.58]
# -----
# -----
# For the game between ['Philadelphia Phillies', 'Toronto Blue Jays'] that starts at 19:37:00 on 2021-05-15,
# The odds on  Unibet are [1.87, 1.97]
# The odds on  BetOnline.ag are [2.09, 1.77]
# The odds on  William Hill (US) are [2.1, 1.77]
# The odds on  BetRivers are [2.1, 1.76]
# The odds on  SugarHouse are [2.1, 1.76]
# The odds on  Barstool Sportsbook are [2.1, 1.76]
# The odds on  Intertops are [2.05, 1.8]
# The odds on  GTbets are [2.09, 1.78]
# The odds on  MyBookie.ag are [2.1, 1.77]
# The odds on  PointsBet (US) are [2.1, 1.76]
# -----
# -----
# For the game between ['Arizona Diamondbacks', 'Washington Nationals'] that starts at 20:10:00 on 2021-05-15,
# The odds on  William Hill (US) are [1.69, 2.25]
# The odds on  BetOnline.ag are [1.69, 2.25]
# The odds on  Unibet are [1.8, 2.06]
# The odds on  Barstool Sportsbook are [1.63, 2.33]
# The odds on  BetRivers are [1.63, 2.33]
# The odds on  SugarHouse are [1.63, 2.33]
# The odds on  GTbets are [1.69, 2.25]
# The odds on  MyBookie.ag are [1.69, 2.25]
# The odds on  PointsBet (US) are [1.69, 2.25]
# -----
# -----
# For the game between ['Cincinnati Reds', 'Colorado Rockies'] that starts at 20:11:00 on 2021-05-15,
# The odds on  BetOnline.ag are [1.89, 1.92]
# The odds on  PointsBet (US) are [1.87, 1.95]
# The odds on  William Hill (US) are [1.87, 1.95]
# The odds on  SugarHouse are [1.88, 1.95]
# The odds on  BetRivers are [1.88, 1.95]
# The odds on  Barstool Sportsbook are [1.88, 1.95]
# The odds on  Unibet are [1.88, 1.96]
# The odds on  Intertops are [1.87, 1.95]
# The odds on  GTbets are [1.89, 1.93]
# The odds on  MyBookie.ag are [1.87, 1.95]
# -----
# -----
# For the game between ['San Diego Padres', 'St. Louis Cardinals'] that starts at 20:40:00 on 2021-05-15,
# The odds on  Unibet are [2.2, 1.7]
# The odds on  BetRivers are [2.8, 1.45]
# The odds on  William Hill (US) are [2.7, 1.5]
# The odds on  GTbets are [2.65, 1.53]
# The odds on  BetOnline.ag are [2.65, 1.52]
# The odds on  PointsBet (US) are [2.6, 1.52]
# The odds on  SugarHouse are [2.8, 1.45]
# The odds on  Barstool Sportsbook are [2.8, 1.45]
# The odds on  MyBookie.ag are [2.6, 1.53]
# -----
# -----
# For the game between ['Cleveland Indians', 'Seattle Mariners'] that starts at 21:10:00 on 2021-05-15,
# The odds on  Unibet are [2.23, 1.7]
# The odds on  BetRivers are [2.55, 1.54]
# The odds on  William Hill (US) are [2.45, 1.59]
# The odds on  GTbets are [2.48, 1.6]
# The odds on  BetOnline.ag are [2.48, 1.59]
# The odds on  PointsBet (US) are [2.45, 1.58]
# The odds on  SugarHouse are [2.55, 1.54]
# The odds on  Barstool Sportsbook are [2.55, 1.54]
# The odds on  MyBookie.ag are [2.45, 1.59]
# The odds on  Intertops are [2.45, 1.61]
# -----
# -----
# For the game between ['Los Angeles Dodgers', 'Miami Marlins'] that starts at 21:10:00 on 2021-05-15,
# The odds on  Unibet are [1.97, 1.87]
# The odds on  BetRivers are [1.75, 2.12]
# The odds on  SugarHouse are [1.75, 2.12]
# The odds on  Barstool Sportsbook are [1.75, 2.12]
# -----
# -----
#
# Remaining requests 422
# Used requests 78
